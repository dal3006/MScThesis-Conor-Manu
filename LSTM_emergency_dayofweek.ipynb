# %% [markdown]
# # LSTM neural network for emergency flow predictions
# This notebook contains the code for applying neural network models to smart city data <br>

# %%
# GPU check:

import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print("Show System RAM Memory: \n \n")
# !cat /proc/meminfo | egrep "MemTotal"
device_lib.list_local_devices()
# Out:
# Show System RAM Memory:
#
#
# MemTotal:       26751688 kB
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2476167028739231308, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6913524411426370760
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17940306808423653580
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15695549568
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11889894462202148499
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
# get additional info about the hardware in the cloud
# %cat /proc/cpuinfo
# %cat /proc/meminfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# MemTotal:       26751672 kB
# MemFree:        22883260 kB
# MemAvailable:   25239916 kB
# Buffers:           95944 kB
# Cached:          2369924 kB
# SwapCached:            0 kB
# Active:          1119104 kB
# Inactive:        2265328 kB
# Active(anon):     762836 kB
# Inactive(anon):     8592 kB
# Active(file):     356268 kB
# Inactive(file):  2256736 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              4524 kB
# Writeback:             0 kB
# AnonPages:        918480 kB
# Mapped:           550188 kB
# Shmem:              9164 kB
# Slab:             196892 kB
# SReclaimable:     133168 kB
# SUnreclaim:        63724 kB
# KernelStack:        4480 kB
# PageTables:         8104 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:    13375836 kB
# Committed_AS:    3356028 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# Percpu:             1904 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      220348 kB
# DirectMap2M:     6070272 kB
# DirectMap1G:    23068672 kB

# %% [markdown]
# Tutorial about google colab and GPU access: <br>
# https://www.youtube.com/watch?v=f1UK8KPt-KU

# %%
# this allows for accessing files stored in your google drive using the path "/gdrive/My Drive/"
# mounting google drive locally:

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# importing local data to google colab:
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b2f53d8a-6169-4adf-81c3-fa1e54309fc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2f53d8a-6169-4adf-81c3-fa1e54309fc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving taxi_series_H to taxi_series_H

# %% [markdown]
# $\textbf{To Do's}$:
# - Cross validate learning rate
# - Number of layers

# %% [markdown]
# $\textbf{Background:}$ Tensors are data structures that you can think of as multi-dimensional arrays. Tensors are represented as n-dimensional arrays of base dataypes such as a string or integer -- they provide a way to generalize vectors and matrices to higher dimensions. The shape of a Tensor defines its number of dimensions and the size of each dimension. The rank of a Tensor provides the number of dimensions. Scalars can be used to create 0-d Tensors. Vectors and lists can be used to create 1-d Tensors. Matrices can be used to create 2-d or higher rank Tensors. The shape of a Tensor provides the number of elements in each Tensor dimension.

# %% [markdown]
# $\textbf{Neural Networks in Tensorflow:}$ We can also define neural networks in TensorFlow. TensorFlow uses a high-level API called Keras that provides a powerful, intuitive framework for building and training deep learning models. <br>
# Tensors can flow through abstract types called $\textit{Layers}$ -- the building blocks of neural networks. Layers implement common neural networks operations, and are used to update weights, compute losses, and define inter-layer connectivity <br>
# <br>
# Conveniently, TensorFlow has defined a number of Layers that are commonly used in neural networks, for example a Dense. Now, instead of using a single Layer to define our simple neural network, we'll use the Sequential model from Keras and a single Dense layer to define our network. With the Sequential API, you can readily create neural networks by stacking together layers like building blocks.

# %% [markdown]
# # Implementation

# %%
## -- Packages  -- ##

# General
import pandas as pd
import numpy as np

# Time formatting
import datetime

# Load and save data
import pickle
# progress bar
from tqdm import tqdm

# Plotting
import matplotlib.pyplot as plt
# %matplotlib inline
#import tikzplotlib as tkz

# %%
##  NN libaries ##
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as K

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt


## ML libraries ##
from keras.wrappers.scikit_learn import KerasRegressor

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import MinMaxScaler

# %%
## Set random seed for reproducable results. see https://machinelearningmastery.com/reproducible-results-neural-networks-keras/ and https://stackoverflow.com/questions/58638701/importerror-cannot-import-name-set-random-seed-from-tensorflow-c-users-po
from numpy.random import seed
seed(123)
#from tensorflow.random import set_random_seed
tf.random.set_seed(123)

# %% [markdown]
# ### Load data

# %%
filename = '/gdrive/My Drive/Colab Notebooks/emergency_dispatches_bronx_H'
infile = open(filename,'rb')
emergency_ts = pickle.load(infile)
infile.close()

# %% [markdown]
# ### Preprocessing for monday the 16

# %%
## Remove last 15 days of data since they are either erroneous or part of the test set to the robustness checks
emergency_ts_mon = emergency_ts.iloc[0:-360]
emergency_ts_mon.shape
# Out:
# (8400,)

# %%
## Set paramaters
input_lags = 60 # 2 and a half times the seasonal period
output_lags = 24 # we predict 24 hours ahead
n_test = 24 # output_lags  (changed)

# %%
## Split data in train and test set
train = emergency_ts_mon[0:-n_test]
test = emergency_ts_mon[-n_test:]
print(train.shape)
print(test.shape)
# Out:
# (8376,)
# (24,)

# %%
## Create lagged values for both input and output window (24)
data = train.copy()
n_train = len(data)

##Create lagged values for input
df = pd.DataFrame()
for i in range(input_lags,0,-1):
    df['t-' + str(i)] = data.shift(i)

##Create lagged values for output
for j in range(0,output_lags,1):
    df['t+' + str(j)] = data.shift(-j)
    
df = df[input_lags:(n_train-output_lags+1)]

# %%
## splitting the training set into labels and features
X_train = df.iloc[:,:input_lags] # from the beginning to input_lags
Y_train = df.iloc[:,input_lags:] # from input_lags to the end

## Use the last window of the training set as the features for the test set. This requires a combination of 
## X_train and Y_train.
X_test = X_train.iloc[len(X_train) - 1,:][output_lags:]
X_test = X_test.append(Y_train.iloc[len(Y_train) - 1,:]).values.reshape(1,input_lags)
Y_test = test[:output_lags].values.reshape(1,output_lags)

X_train = X_train.values # 54 steps back (54 lags)
Y_train = Y_train.values # 24 steps ahead

print("X_train: " + "type: " + str(type(X_train)) + "\tshape: " + str(X_train.shape))
print("Y_train: " + "type: " + str(type(Y_train)) + "\tshape: " + str(Y_train.shape))
print("X_test: " + "type: " + str(type(X_test)) + "\tshape: " + str(X_test.shape))
print("Y_test: " + "type: " + str(type(Y_test)) + "\tshape: " + str(Y_test.shape))
# Out:
# X_train: type: <class 'numpy.ndarray'>	shape: (8293, 60)
# Y_train: type: <class 'numpy.ndarray'>	shape: (8293, 24)
# X_test: type: <class 'numpy.ndarray'>	shape: (1, 60)
# Y_test: type: <class 'numpy.ndarray'>	shape: (1, 24)

# %% [markdown]
# # Building the LSTM neural network model

# %% [markdown]
# # Method 1 (Keras)

# %% [markdown]
# Tensorflow 2.0 Impelementation <br>
# (tf.keras is TensorFlow's implementation of the Keras API specification. This is a high-level API to build and train models that includes first-class support for TensorFlow-specific functionality)

# %% [markdown]
# TF 2 keras RNN tutorial
# https://www.tensorflow.org/guide/keras/rnn <br>
# TF 2 time series forecasting tutorial
# https://www.tensorflow.org/tutorials/structured_data/time_series

# %%
# configuring the inputs for the model
# For Keras, the input has to be in the shape (samples, time steps, features)
# 24 timestep with n features where n is equal to the shape of column [1] of X_train or X_test

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# creating a leaky_relu activation function

def my_leaky_relu(x):
    return tf.nn.leaky_relu(x)

# %% [markdown]
# ## Fitting the optimal model with all gridsearched parameters

# %%
# fitting the optimal GRU model with the gridsearched hyperparameters
LSTM_model = tf.keras.Sequential()

# Add a GRU layer with 128 units (=dimensionality of the output space = number of neurons)
# option1: return sequences returns the hidden state output for each input time step.
# option2: return state returns the hidden state output and cell state for the last input time step.
# The output of GRU will be a 3D tensor of shape (batch_size, timesteps, 128)
LSTM_model.add(tf.keras.layers.LSTM(units=1000, return_sequences = False, input_shape = (1,60), activation=my_leaky_relu, dropout = 0.0))

# output layer 
LSTM_model.add(tf.keras.layers.Dense(24))
# the compile() method configures the model for training
LSTM_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.01),
              loss=tf.keras.losses.mean_squared_error,
              metrics=['mean_squared_error'])
LSTM_model.fit(X_train, Y_train, epochs= 500, batch_size=400, verbose=1)
# Out:
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/500
# 21/21 [==============================] - 0s 7ms/step - loss: 1722.2474 - mean_squared_error: 1722.2473
# Epoch 2/500
# 21/21 [==============================] - 0s 7ms/step - loss: 112.2650 - mean_squared_error: 112.2650
# Epoch 3/500
# 21/21 [==============================] - 0s 7ms/step - loss: 78.6276 - mean_squared_error: 78.6276
# Epoch 4/500
# 21/21 [==============================] - 0s 7ms/step - loss: 72.3434 - mean_squared_error: 72.3434
# Epoch 5/500
# 21/21 [==============================] - 0s 7ms/step - loss: 68.0636 - mean_squared_error: 68.0636
# Epoch 6/500
# 21/21 [==============================] - 0s 7ms/step - loss: 65.7552 - mean_squared_error: 65.7552
# Epoch 7/500
# 21/21 [==============================] - 0s 7ms/step - loss: 63.9096 - mean_squared_error: 63.9096
# Epoch 8/500
# 21/21 [==============================] - 0s 7ms/step - loss: 62.9096 - mean_squared_error: 62.9096
# Epoch 9/500
# 21/21 [==============================] - 0s 7ms/step - loss: 62.6546 - mean_squared_error: 62.6546
# Epoch 10/500
# 21/21 [==============================] - 0s 7ms/step - loss: 62.6539 - mean_squared_error: 62.6539
# Epoch 11/500
# 21/21 [==============================] - 0s 7ms/step - loss: 62.3094 - mean_squared_error: 62.3094
# Epoch 12/500
500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.8332 - mean_squared_error: 51.8332
# Epoch 169/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3917 - mean_squared_error: 52.3917
# Epoch 170/500
# 21/21 [==============================] - 0s 7ms/step - loss: 53.0188 - mean_squared_error: 53.0188
# Epoch 171/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3397 - mean_squared_error: 52.3397
# Epoch 172/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0506 - mean_squared_error: 52.0506
# Epoch 173/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4125 - mean_squared_error: 52.4125
# Epoch 174/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.7985 - mean_squared_error: 51.7985
# Epoch 175/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3952 - mean_squared_error: 52.3952
# Epoch 176/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.4295 - mean_squared_error: 51.4295
# Epoch 177/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3363 - mean_squared_error: 52.3363
# Epoch 178/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.8062 - mean_squared_error: 52.8062
# Epoch 179/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.6471 - mean_squared_error: 52.6471
# Epoch 180/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9462 - mean_squared_error: 51.9462
# Epoch 181/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9092 - mean_squared_error: 51.9092
# Epoch 182/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0599 - mean_squared_error: 52.0599
# Epoch 183/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.1281 - mean_squared_error: 52.1281
# Epoch 184/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.6762 - mean_squared_error: 51.6762
# Epoch 185/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3309 - mean_squared_error: 52.3309
# Epoch 186/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9381 - mean_squared_error: 51.9381
# Epoch 187/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.6642 - mean_squared_error: 51.6642
# Epoch 188/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9000 - mean_squared_error: 51.9000
# Epoch 189/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.1259 - mean_squared_error: 52.1259
# Epoch 190/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0442 - mean_squared_error: 52.0442
# Epoch 191/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.9172 - mean_squared_error: 52.9172
# Epoch 192/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.6401 - mean_squared_error: 51.6401
# Epoch 193/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3272 - mean_squared_error: 52.3272
# Epoch 194/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.6833 - mean_squared_error: 51.6833
# Epoch 195/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4975 - mean_squared_error: 52.4975
# Epoch 196/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.8592 - mean_squared_error: 51.8592
# Epoch 197/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.4497 - mean_squared_error: 51.4497
# Epoch 198/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.3682 - mean_squared_error: 51.3682
# Epoch 199/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.3021 - mean_squared_error: 51.3021
# Epoch 200/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5815 - mean_squared_error: 51.5815
# Epoch 201/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.1668 - mean_squared_error: 52.1668
# Epoch 202/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.3061 - mean_squared_error: 51.3061
# Epoch 203/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.4958 - mean_squared_error: 51.4958
# Epoch 204/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0034 - mean_squared_error: 52.0034
# Epoch 205/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3282 - mean_squared_error: 52.3282
# Epoch 206/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9896 - mean_squared_error: 51.9896
# Epoch 207/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.4466 - mean_squared_error: 51.4466
# Epoch 208/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9260 - mean_squared_error: 51.9260
# Epoch 209/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0959 - mean_squared_error: 52.0959
# Epoch 210/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2912 - mean_squared_error: 51.2912
# Epoch 211/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.6735 - mean_squared_error: 51.6735
# Epoch 212/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4680 - mean_squared_error: 52.4680
# Epoch 213/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.7926 - mean_squared_error: 51.7926
# Epoch 214/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9840 - mean_squared_error: 51.9840
# Epoch 215/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.4432 - mean_squared_error: 51.4432
# Epoch 216/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5612 - mean_squared_error: 51.5612
# Epoch 217/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9613 - mean_squared_error: 51.9613
# Epoch 218/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9334 - mean_squared_error: 51.9334
# Epoch 219/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9632 - mean_squared_error: 51.9632
# Epoch 220/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9253 - mean_squared_error: 51.9253
# Epoch 221/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5816 - mean_squared_error: 51.5816
# Epoch 222/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0553 - mean_squared_error: 52.0553
# Epoch 223/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4885 - mean_squared_error: 52.4885
# Epoch 224/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5952 - mean_squared_error: 51.5952
# Epoch 225/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.2933 - mean_squared_error: 52.2933
# Epoch 226/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.
500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4287 - mean_squared_error: 52.4287
# Epoch 403/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1715 - mean_squared_error: 51.1715
# Epoch 404/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3059 - mean_squared_error: 52.3059
# Epoch 405/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.4038 - mean_squared_error: 51.4038
# Epoch 406/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1818 - mean_squared_error: 51.1818
# Epoch 407/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.3868 - mean_squared_error: 52.3868
# Epoch 408/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.5168 - mean_squared_error: 52.5168
# Epoch 409/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0729 - mean_squared_error: 52.0729
# Epoch 410/500
# 21/21 [==============================] - 0s 7ms/step - loss: 53.4853 - mean_squared_error: 53.4853
# Epoch 411/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.2383 - mean_squared_error: 52.2383
# Epoch 412/500
# 21/21 [==============================] - 0s 7ms/step - loss: 53.2023 - mean_squared_error: 53.2023
# Epoch 413/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.7234 - mean_squared_error: 52.7234
# Epoch 414/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.4422 - mean_squared_error: 51.4422
# Epoch 415/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.6293 - mean_squared_error: 50.6293
# Epoch 416/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.9351 - mean_squared_error: 51.9351
# Epoch 417/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0488 - mean_squared_error: 52.0488
# Epoch 418/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.7662 - mean_squared_error: 52.7662
# Epoch 419/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1182 - mean_squared_error: 51.1182
# Epoch 420/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.0160 - mean_squared_error: 51.0160
# Epoch 421/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1618 - mean_squared_error: 51.1618
# Epoch 422/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.9160 - mean_squared_error: 50.9160
# Epoch 423/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.8216 - mean_squared_error: 50.8216
# Epoch 424/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.0570 - mean_squared_error: 51.0570
# Epoch 425/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.7217 - mean_squared_error: 51.7217
# Epoch 426/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.7351 - mean_squared_error: 51.7351
# Epoch 427/500
# 21/21 [==============================] - 0s 7ms/step - loss: 53.0974 - mean_squared_error: 53.0974
# Epoch 428/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.6000 - mean_squared_error: 52.6000
# Epoch 429/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0209 - mean_squared_error: 52.0209
# Epoch 430/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.7491 - mean_squared_error: 51.7491
# Epoch 431/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5944 - mean_squared_error: 51.5944
# Epoch 432/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0444 - mean_squared_error: 52.0444
# Epoch 433/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.7922 - mean_squared_error: 50.7922
# Epoch 434/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1976 - mean_squared_error: 51.1976
# Epoch 435/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.7579 - mean_squared_error: 50.7579
# Epoch 436/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.8245 - mean_squared_error: 50.8245
# Epoch 437/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1080 - mean_squared_error: 51.1080
# Epoch 438/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2767 - mean_squared_error: 51.2767
# Epoch 439/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.5045 - mean_squared_error: 50.5045
# Epoch 440/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2171 - mean_squared_error: 51.2171
# Epoch 441/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.5536 - mean_squared_error: 50.5536
# Epoch 442/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5603 - mean_squared_error: 51.5603
# Epoch 443/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2873 - mean_squared_error: 51.2873
# Epoch 444/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.5584 - mean_squared_error: 50.5584
# Epoch 445/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.8859 - mean_squared_error: 51.8859
# Epoch 446/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.3046 - mean_squared_error: 51.3046
# Epoch 447/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1418 - mean_squared_error: 51.1418
# Epoch 448/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.2475 - mean_squared_error: 52.2475
# Epoch 449/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2803 - mean_squared_error: 51.2803
# Epoch 450/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.8590 - mean_squared_error: 51.8590
# Epoch 451/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.8049 - mean_squared_error: 52.8049
# Epoch 452/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.5154 - mean_squared_error: 52.5154
# Epoch 453/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0977 - mean_squared_error: 52.0977
# Epoch 454/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2309 - mean_squared_error: 51.2309
# Epoch 455/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2997 - mean_squared_error: 51.2997
# Epoch 456/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.6735 - mean_squared_error: 51.6735
# Epoch 457/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.4082 - mean_squared_error: 51.4082
# Epoch 458/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5307 - mean_squared_error: 51.5307
# Epoch 459/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.6180 - mean_squared_error: 51.6180
# Epoch 460/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1291 - mean_squared_error: 51.1291
# Epoch 461/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.6354 - mean_squared_error: 52.6354
# Epoch 462/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.7995 - mean_squared_error: 51.7995
# Epoch 463/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.7344 - mean_squared_error: 50.7344
# Epoch 464/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2552 - mean_squared_error: 51.2552
# Epoch 465/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.2465 - mean_squared_error: 50.2465
# Epoch 466/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.8130 - mean_squared_error: 51.8130
# Epoch 467/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.8535 - mean_squared_error: 51.8535
# Epoch 468/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1040 - mean_squared_error: 51.1040
# Epoch 469/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0518 - mean_squared_error: 52.0518
# Epoch 470/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0405 - mean_squared_error: 52.0405
# Epoch 471/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.5833 - mean_squared_error: 50.5833
# Epoch 472/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.0028 - mean_squared_error: 51.0028
# Epoch 473/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0653 - mean_squared_error: 52.0653
# Epoch 474/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.3238 - mean_squared_error: 51.3238
# Epoch 475/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4818 - mean_squared_error: 52.4818
# Epoch 476/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.2389 - mean_squared_error: 52.2389
# Epoch 477/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.1889 - mean_squared_error: 52.1889
# Epoch 478/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.0259 - mean_squared_error: 52.0259
# Epoch 479/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4888 - mean_squared_error: 52.4888
# Epoch 480/500
# 21/21 [==============================] - 0s 7ms/step - loss: 54.2249 - mean_squared_error: 54.2249
# Epoch 481/500
# 21/21 [==============================] - 0s 7ms/step - loss: 54.8010 - mean_squared_error: 54.8010
# Epoch 482/500
# 21/21 [==============================] - 0s 7ms/step - loss: 54.9748 - mean_squared_error: 54.9748
# Epoch 483/500
# 21/21 [==============================] - 0s 7ms/step - loss: 54.2723 - mean_squared_error: 54.2723
# Epoch 484/500
# 21/21 [==============================] - 0s 7ms/step - loss: 53.4487 - mean_squared_error: 53.4487
# Epoch 485/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4444 - mean_squared_error: 52.4444
# Epoch 486/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.8478 - mean_squared_error: 52.8478
# Epoch 487/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.4823 - mean_squared_error: 52.4823
# Epoch 488/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5504 - mean_squared_error: 51.5504
# Epoch 489/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5939 - mean_squared_error: 51.5939
# Epoch 490/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.6154 - mean_squared_error: 51.6154
# Epoch 491/500
# 21/21 [==============================] - 0s 7ms/step - loss: 52.8496 - mean_squared_error: 52.8496
# Epoch 492/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.8619 - mean_squared_error: 51.8619
# Epoch 493/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.0560 - mean_squared_error: 51.0560
# Epoch 494/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.0129 - mean_squared_error: 51.0129
# Epoch 495/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.2783 - mean_squared_error: 51.2783
# Epoch 496/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.1796 - mean_squared_error: 51.1796
# Epoch 497/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.5493 - mean_squared_error: 51.5493
# Epoch 498/500
# 21/21 [==============================] - 0s 7ms/step - loss: 50.7859 - mean_squared_error: 50.7859
# Epoch 499/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.0452 - mean_squared_error: 51.0452
# Epoch 500/500
# 21/21 [==============================] - 0s 7ms/step - loss: 51.0433 - mean_squared_error: 51.0433

# %%
# making predictions (regular GRU)
y_train_pred = LSTM_model.predict(X_train)
y_test_pred = LSTM_model.predict(X_test)

# %%
# RMSE LSTM forecast
mse_LSTM = mean_squared_error(Y_test, y_test_pred)
sqrt(mse_LSTM)

# %% [markdown]
# ## Preprocessing for tuesday the 17

# %%
##
emergency_ts_tue = emergency_ts.iloc[0:-360 + 24]
emergency_ts_tue.shape
# Out:
# (8424,)

# %%
## Set paramaters
input_lags = 60 # 2 and a half times the seasonal period
output_lags = 24 # we predict 24 hours ahead
n_test = 24 # output_lags  (changed)

# %%
## Split data in train and test set
train = emergency_ts_tue[0:-n_test]
test = emergency_ts_tue[-n_test:]
print(train.shape)
print(test.shape)
# Out:
# (8400,)
# (24,)

# %%
## Create lagged values for both input and output window (24)
data = train.copy()
n_train = len(data)

##Create lagged values for input
df = pd.DataFrame()
for i in range(input_lags,0,-1):
    df['t-' + str(i)] = data.shift(i)

##Create lagged values for output
for j in range(0,output_lags,1):
    df['t+' + str(j)] = data.shift(-j)
    
df = df[input_lags:(n_train-output_lags+1)]

# %%
## splitting the training set into labels and features
X_train = df.iloc[:,:input_lags] # from the beginning to input_lags
Y_train = df.iloc[:,input_lags:] # from input_lags to the end

## Use the last window of the training set as the features for the test set. This requires a combination of 
## X_train and Y_train.
X_test = X_train.iloc[len(X_train) - 1,:][output_lags:]
X_test = X_test.append(Y_train.iloc[len(Y_train) - 1,:]).values.reshape(1,input_lags)
Y_test = test[:output_lags].values.reshape(1,output_lags)

X_train = X_train.values # 54 steps back (54 lags)
Y_train = Y_train.values # 24 steps ahead

print("X_train: " + "type: " + str(type(X_train)) + "\tshape: " + str(X_train.shape))
print("Y_train: " + "type: " + str(type(Y_train)) + "\tshape: " + str(Y_train.shape))
print("X_test: " + "type: " + str(type(X_test)) + "\tshape: " + str(X_test.shape))
print("Y_test: " + "type: " + str(type(Y_test)) + "\tshape: " + str(Y_test.shape))
# Out:
# X_train: type: <class 'numpy.ndarray'>	shape: (8317, 60)
# Y_train: type: <class 'numpy.ndarray'>	shape: (8317, 24)
# X_test: type: <class 'numpy.ndarray'>	shape: (1, 60)
# Y_test: type: <class 'numpy.ndarray'>	shape: (1, 24)

# %%
# configuring the inputs for the model
# For Keras, the input has to be in the shape (samples, time steps, features)
# 24 timestep with n features where n is equal to the shape of column [1] of X_train or X_test

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# making predictions (regular GRU)
y_train_pred = LSTM_model.predict(X_train)
y_test_pred = LSTM_model.predict(X_test)

# %%
# RMSE LSTM forecast
mse_LSTM = mean_squared_error(Y_test, y_test_pred)
sqrt(mse_LSTM)
# Out:
# 5.880219203020446

# %% [markdown]
# ## Preprocessing for wedensday the 18

# %%
## 
emergency_ts_wed = emergency_ts.iloc[0:-360 + 24*2]
emergency_ts_wed.shape
# Out:
# (8448,)

# %%
## Set paramaters
input_lags = 60 # 2 and a half times the seasonal period
output_lags = 24 # we predict 24 hours ahead
n_test = 24 # output_lags  (changed)

# %%
## Split data in train and test set
train = emergency_ts_wed[0:-n_test]
test = emergency_ts_wed[-n_test:]
print(train.shape)
print(test.shape)
# Out:
# (8424,)
# (24,)

# %%
## Create lagged values for both input and output window (24)
data = train.copy()
n_train = len(data)

##Create lagged values for input
df = pd.DataFrame()
for i in range(input_lags,0,-1):
    df['t-' + str(i)] = data.shift(i)

##Create lagged values for output
for j in range(0,output_lags,1):
    df['t+' + str(j)] = data.shift(-j)
    
df = df[input_lags:(n_train-output_lags+1)]

# %%
## splitting the training set into labels and features
X_train = df.iloc[:,:input_lags] # from the beginning to input_lags
Y_train = df.iloc[:,input_lags:] # from input_lags to the end

## Use the last window of the training set as the features for the test set. This requires a combination of 
## X_train and Y_train.
X_test = X_train.iloc[len(X_train) - 1,:][output_lags:]
X_test = X_test.append(Y_train.iloc[len(Y_train) - 1,:]).values.reshape(1,input_lags)
Y_test = test[:output_lags].values.reshape(1,output_lags)

X_train = X_train.values # 54 steps back (54 lags)
Y_train = Y_train.values # 24 steps ahead

print("X_train: " + "type: " + str(type(X_train)) + "\tshape: " + str(X_train.shape))
print("Y_train: " + "type: " + str(type(Y_train)) + "\tshape: " + str(Y_train.shape))
print("X_test: " + "type: " + str(type(X_test)) + "\tshape: " + str(X_test.shape))
print("Y_test: " + "type: " + str(type(Y_test)) + "\tshape: " + str(Y_test.shape))
# Out:
# X_train: type: <class 'numpy.ndarray'>	shape: (8341, 60)
# Y_train: type: <class 'numpy.ndarray'>	shape: (8341, 24)
# X_test: type: <class 'numpy.ndarray'>	shape: (1, 60)
# Y_test: type: <class 'numpy.ndarray'>	shape: (1, 24)

# %%
# configuring the inputs for the model
# For Keras, the input has to be in the shape (samples, time steps, features)
# 24 timestep with n features where n is equal to the shape of column [1] of X_train or X_test

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# making predictions (regular GRU)
y_train_pred = LSTM_model.predict(X_train)
y_test_pred = LSTM_model.predict(X_test)

# %%
# RMSE LSTM forecast
mse_LSTM = mean_squared_error(Y_test, y_test_pred)
sqrt(mse_LSTM)
# Out:
# 5.39528047151096

# %% [markdown]
# ## Preprocessing for thursday the 19

# %%
##
emergency_ts_thu = emergency_ts.iloc[0:-360 + 24*3]
emergency_ts_thu.shape
# Out:
# (8472,)

# %%
## Set paramaters
input_lags = 60 # 2 and a half times the seasonal period
output_lags = 24 # we predict 24 hours ahead
n_test = 24 # output_lags  (changed)

# %%
## Split data in train and test set
train = emergency_ts_thu[0:-n_test]
test = emergency_ts_thu[-n_test:]
print(train.shape)
print(test.shape)
# Out:
# (8448,)
# (24,)

# %%
## Create lagged values for both input and output window (24)
data = train.copy()
n_train = len(data)

##Create lagged values for input
df = pd.DataFrame()
for i in range(input_lags,0,-1):
    df['t-' + str(i)] = data.shift(i)

##Create lagged values for output
for j in range(0,output_lags,1):
    df['t+' + str(j)] = data.shift(-j)
    
df = df[input_lags:(n_train-output_lags+1)]

# %%
## splitting the training set into labels and features
X_train = df.iloc[:,:input_lags] # from the beginning to input_lags
Y_train = df.iloc[:,input_lags:] # from input_lags to the end

## Use the last window of the training set as the features for the test set. This requires a combination of 
## X_train and Y_train.
X_test = X_train.iloc[len(X_train) - 1,:][output_lags:]
X_test = X_test.append(Y_train.iloc[len(Y_train) - 1,:]).values.reshape(1,input_lags)
Y_test = test[:output_lags].values.reshape(1,output_lags)

X_train = X_train.values # 54 steps back (54 lags)
Y_train = Y_train.values # 24 steps ahead

print("X_train: " + "type: " + str(type(X_train)) + "\tshape: " + str(X_train.shape))
print("Y_train: " + "type: " + str(type(Y_train)) + "\tshape: " + str(Y_train.shape))
print("X_test: " + "type: " + str(type(X_test)) + "\tshape: " + str(X_test.shape))
print("Y_test: " + "type: " + str(type(Y_test)) + "\tshape: " + str(Y_test.shape))
# Out:
# X_train: type: <class 'numpy.ndarray'>	shape: (8365, 60)
# Y_train: type: <class 'numpy.ndarray'>	shape: (8365, 24)
# X_test: type: <class 'numpy.ndarray'>	shape: (1, 60)
# Y_test: type: <class 'numpy.ndarray'>	shape: (1, 24)

# %%
# configuring the inputs for the model
# For Keras, the input has to be in the shape (samples, time steps, features)
# 24 timestep with n features where n is equal to the shape of column [1] of X_train or X_test

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# making predictions (regular GRU)
y_train_pred = LSTM_model.predict(X_train)
y_test_pred = LSTM_model.predict(X_test)

# %%
# RMSE LSTM forecast
mse_LSTM = mean_squared_error(Y_test, y_test_pred)
sqrt(mse_LSTM)
# Out:
# 5.017862019850635

# %% [markdown]
# ## Preprocessing for friday the 20

# %%
## 
emergency_ts_fri = emergency_ts.iloc[0:-360 + 24*4] 
emergency_ts_fri.shape
# Out:
# (8496,)

# %%
## Set paramaters
input_lags = 60 # 2 and a half times the seasonal period
output_lags = 24 # we predict 24 hours ahead
n_test = 24 # output_lags  (changed)

# %%
## Split data in train and test set
train = emergency_ts_fri[0:-n_test]
test = emergency_ts_fri[-n_test:]
print(train.shape)
print(test.shape)
# Out:
# (8472,)
# (24,)

# %%
## Create lagged values for both input and output window (24)
data = train.copy()
n_train = len(data)

##Create lagged values for input
df = pd.DataFrame()
for i in range(input_lags,0,-1):
    df['t-' + str(i)] = data.shift(i)

##Create lagged values for output
for j in range(0,output_lags,1):
    df['t+' + str(j)] = data.shift(-j)
    
df = df[input_lags:(n_train-output_lags+1)]

# %%
## splitting the training set into labels and features
X_train = df.iloc[:,:input_lags] # from the beginning to input_lags
Y_train = df.iloc[:,input_lags:] # from input_lags to the end

## Use the last window of the training set as the features for the test set. This requires a combination of 
## X_train and Y_train.
X_test = X_train.iloc[len(X_train) - 1,:][output_lags:]
X_test = X_test.append(Y_train.iloc[len(Y_train) - 1,:]).values.reshape(1,input_lags)
Y_test = test[:output_lags].values.reshape(1,output_lags)

X_train = X_train.values # 54 steps back (54 lags)
Y_train = Y_train.values # 24 steps ahead

print("X_train: " + "type: " + str(type(X_train)) + "\tshape: " + str(X_train.shape))
print("Y_train: " + "type: " + str(type(Y_train)) + "\tshape: " + str(Y_train.shape))
print("X_test: " + "type: " + str(type(X_test)) + "\tshape: " + str(X_test.shape))
print("Y_test: " + "type: " + str(type(Y_test)) + "\tshape: " + str(Y_test.shape))
# Out:
# X_train: type: <class 'numpy.ndarray'>	shape: (8389, 60)
# Y_train: type: <class 'numpy.ndarray'>	shape: (8389, 24)
# X_test: type: <class 'numpy.ndarray'>	shape: (1, 60)
# Y_test: type: <class 'numpy.ndarray'>	shape: (1, 24)

# %%
# configuring the inputs for the model
# For Keras, the input has to be in the shape (samples, time steps, features)
# 24 timestep with n features where n is equal to the shape of column [1] of X_train or X_test

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# making predictions (regular GRU)
y_train_pred = LSTM_model.predict(X_train)
y_test_pred = LSTM_model.predict(X_test)

# %%
# RMSE LSTM forecast
mse_LSTM = mean_squared_error(Y_test, y_test_pred)
sqrt(mse_LSTM)
# Out:
# 5.442430204607574

# %% [markdown]
# ## Preprocessing for saturday the 21

# %%
##
emergency_ts_sat = emergency_ts.iloc[0:-360 + 24*5]
emergency_ts_sat.shape
# Out:
# (8520,)

# %%
## Set paramaters
input_lags = 60 # 2 and a half times the seasonal period
output_lags = 24 # we predict 24 hours ahead
n_test = 24 # output_lags  (changed)

# %%
## Split data in train and test set
train = emergency_ts_sat[0:-n_test]
test = emergency_ts_sat[-n_test:]
print(train.shape)
print(test.shape)
# Out:
# (8496,)
# (24,)

# %%
## Create lagged values for both input and output window (24)
data = train.copy()
n_train = len(data)

##Create lagged values for input
df = pd.DataFrame()
for i in range(input_lags,0,-1):
    df['t-' + str(i)] = data.shift(i)

##Create lagged values for output
for j in range(0,output_lags,1):
    df['t+' + str(j)] = data.shift(-j)
    
df = df[input_lags:(n_train-output_lags+1)]

# %%
## splitting the training set into labels and features
X_train = df.iloc[:,:input_lags] # from the beginning to input_lags
Y_train = df.iloc[:,input_lags:] # from input_lags to the end

## Use the last window of the training set as the features for the test set. This requires a combination of 
## X_train and Y_train.
X_test = X_train.iloc[len(X_train) - 1,:][output_lags:]
X_test = X_test.append(Y_train.iloc[len(Y_train) - 1,:]).values.reshape(1,input_lags)
Y_test = test[:output_lags].values.reshape(1,output_lags)

X_train = X_train.values # 54 steps back (54 lags)
Y_train = Y_train.values # 24 steps ahead

print("X_train: " + "type: " + str(type(X_train)) + "\tshape: " + str(X_train.shape))
print("Y_train: " + "type: " + str(type(Y_train)) + "\tshape: " + str(Y_train.shape))
print("X_test: " + "type: " + str(type(X_test)) + "\tshape: " + str(X_test.shape))
print("Y_test: " + "type: " + str(type(Y_test)) + "\tshape: " + str(Y_test.shape))
# Out:
# X_train: type: <class 'numpy.ndarray'>	shape: (8413, 60)
# Y_train: type: <class 'numpy.ndarray'>	shape: (8413, 24)
# X_test: type: <class 'numpy.ndarray'>	shape: (1, 60)
# Y_test: type: <class 'numpy.ndarray'>	shape: (1, 24)

# %%
# configuring the inputs for the model
# For Keras, the input has to be in the shape (samples, time steps, features)
# 24 timestep with n features where n is equal to the shape of column [1] of X_train or X_test

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# making predictions (regular GRU)
y_train_pred = LSTM_model.predict(X_train)
y_test_pred = LSTM_model.predict(X_test)

# %%
# RMSE LSTM forecast
mse_LSTM = mean_squared_error(Y_test, y_test_pred)
sqrt(mse_LSTM)
# Out:
# 6.499081970529635

# %% [markdown]
# ## Preprocessing for sunday the 22

# %%
##
emergency_ts_sun = emergency_ts.iloc[0:-360 + 24*6]
emergency_ts_sun.shape
# Out:
# (8544,)

# %%
## Set paramaters
input_lags = 60 # 2 and a half times the seasonal period
output_lags = 24 # we predict 24 hours ahead
n_test = 24 # output_lags  (changed)

# %%
## Split data in train and test set
train = emergency_ts_sun[0:-n_test]
test = emergency_ts_sun[-n_test:]
print(train.shape)
print(test.shape)
# Out:
# (8520,)
# (24,)

# %%
## Create lagged values for both input and output window (24)
data = train.copy()
n_train = len(data)

##Create lagged values for input
df = pd.DataFrame()
for i in range(input_lags,0,-1):
    df['t-' + str(i)] = data.shift(i)

##Create lagged values for output
for j in range(0,output_lags,1):
    df['t+' + str(j)] = data.shift(-j)
    
df = df[input_lags:(n_train-output_lags+1)]

# %%
## splitting the training set into labels and features
X_train = df.iloc[:,:input_lags] # from the beginning to input_lags
Y_train = df.iloc[:,input_lags:] # from input_lags to the end

## Use the last window of the training set as the features for the test set. This requires a combination of 
## X_train and Y_train.
X_test = X_train.iloc[len(X_train) - 1,:][output_lags:]
X_test = X_test.append(Y_train.iloc[len(Y_train) - 1,:]).values.reshape(1,input_lags)
Y_test = test[:output_lags].values.reshape(1,output_lags)

X_train = X_train.values # 54 steps back (54 lags)
Y_train = Y_train.values # 24 steps ahead

print("X_train: " + "type: " + str(type(X_train)) + "\tshape: " + str(X_train.shape))
print("Y_train: " + "type: " + str(type(Y_train)) + "\tshape: " + str(Y_train.shape))
print("X_test: " + "type: " + str(type(X_test)) + "\tshape: " + str(X_test.shape))
print("Y_test: " + "type: " + str(type(Y_test)) + "\tshape: " + str(Y_test.shape))
# Out:
# X_train: type: <class 'numpy.ndarray'>	shape: (8437, 60)
# Y_train: type: <class 'numpy.ndarray'>	shape: (8437, 24)
# X_test: type: <class 'numpy.ndarray'>	shape: (1, 60)
# Y_test: type: <class 'numpy.ndarray'>	shape: (1, 24)

# %%
# configuring the inputs for the model
# For Keras, the input has to be in the shape (samples, time steps, features)
# 24 timestep with n features where n is equal to the shape of column [1] of X_train or X_test

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# making predictions (regular GRU)
y_train_pred = LSTM_model.predict(X_train)
y_test_pred = LSTM_model.predict(X_test)

# %%
# RMSE LSTM forecast
mse_LSTM = mean_squared_error(Y_test, y_test_pred)
sqrt(mse_LSTM)
# Out:
# 5.493674684757621
